# %% [markdown]
# <a href="https://colab.research.google.com/github/robitussin/CCDEPLRL_EXERCISES/blob/main/exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Instructions
#
#
# 1. Collect **100-200 images** of the fruit
# 2. Split the collected images for train, test and validation. Please make sure that there are no duplicate images. Images that are used in train should not appear in test, validation and vice versa.
# 3. Combine the collected images together with the images of apple, orange and banana. They  are already available in the link below: https://github.com/robitussin/tensorflow_lite_projects/tree/main/images/fruits
# 4. Create and train a Convolutional Neural Network (CNN).
# 5. Save the model as **"model.tflite"**
# 6. Create a folder named **exercise_4** in your **CCDEPLRL_EXERCISES_COM222_ML** repository.
# 7. Upload the **python notebook (.ipynb)** and the **model (.tflite)** in the exercise_3 folder
#
# Deadline of submission is on **April 22, 2025**

# %% [markdown]
# ## Model

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# Import the libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Hyperparameters: Set the image size and batch size

# %%
img_height, img_width = 32, 32
batch_size = 20

# %% [markdown]
# Split the images into train, validation and test

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/ColabNotebooks/exercise4/fruits/fruits/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/ColabNotebooks/exercise4/fruits/fruits/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/ColabNotebooks/exercise4/fruits/fruits/test",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 622 files belonging to 4 classes.
# Found 622 files belonging to 4 classes.
# Found 177 files belonging to 4 classes.

# %% [markdown]
# Display sample images from the dataset

# %%
class_names = ["apple", "banana", "grape", "orange"]

plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Create the Convolutional Neural Network Model (CNN)

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

# %%
model = tf.keras.Sequential(
    [
    tf.keras.layers.Rescaling(1./255),
    data_augmentation,

    tf.keras.layers.Conv2D(32, 3, activation="relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(64, 3, activation="relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(128, 3, activation="relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(4)
]
)

# %% [markdown]
# Define the optimizer and loss function

# %%
model.compile(
    optimizer="adam",
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics=['accuracy']
)

# %% [markdown]
# Train the model

# %%
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 35
)
# Out:
# Epoch 1/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 191ms/step - accuracy: 0.4212 - loss: 1.2473 - val_accuracy: 0.4132 - val_loss: 1.4011
# Epoch 2/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - accuracy: 0.7579 - loss: 0.6403 - val_accuracy: 0.8778 - val_loss: 0.3358
# Epoch 3/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - accuracy: 0.8577 - loss: 0.4212 - val_accuracy: 0.6849 - val_loss: 1.0073
# Epoch 4/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - accuracy: 0.8524 - loss: 0.4137 - val_accuracy: 0.9180 - val_loss: 0.2596
# Epoch 5/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.9203 - loss: 0.2430 - val_accuracy: 0.8826 - val_loss: 0.3288
# Epoch 6/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.8913 - loss: 0.3059 - val_accuracy: 0.9486 - val_loss: 0.1593
# Epoch 7/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - accuracy: 0.9244 - loss: 0.1976 - val_accuracy: 0.9582 - val_loss: 0.1318
# Epoch 8/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.9178 - loss: 0.2504 - val_accuracy: 0.9566 - val_loss: 0.1557
# Epoch 9/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.9213 - loss: 0.2287 - val_accuracy: 0.9373 - val_loss: 0.2028
# Epoch 10/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - accuracy: 0.9655 - loss: 0.1334 - val_accuracy: 0.9727 - val_loss: 0.0916
# Epoch 11/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.9699 - loss: 0.0968 - val_accuracy: 0.9614 - val_loss: 0.1060
# Epoch 12/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.9863 - loss: 0.0783 - val_accuracy: 0.9662 - val_loss: 0.0979
# Epoch 13/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 240ms/step - accuracy: 0.9307 - loss: 0.1954 - val_accuracy: 0.9534 - val_loss: 0.1413
# Epoch 14/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.9450 - loss: 0.1759 - val_accuracy: 0.9775 - val_loss: 0.0633
# Epoch 15/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - accuracy: 0.9621 - loss: 0.1099 - val_accuracy: 0.9662 - val_loss: 0.1189
# Epoch 16/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9626 - loss: 0.0949 - val_accuracy: 0.8987 - val_loss: 0.2899
# Epoch 17/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9772 - loss: 0.0734 - val_accuracy: 0.9855 - val_loss: 0.0458
# Epoch 18/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 197ms/step - accuracy: 0.9690 - loss: 0.0864 - val_accuracy: 0.9678 - val_loss: 0.0994
# Epoch 19/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 242ms/step - accuracy: 0.9758 - loss: 0.0796 - val_accuracy: 0.9759 - val_loss: 0.0656
# Epoch 20/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - accuracy: 0.9746 - loss: 0.0747 - val_accuracy: 0.9437 - val_loss: 0.1629
# Epoch 21/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9564 - loss: 0.1103 - val_accuracy: 0.9678 - val_loss: 0.0975
# Epoch 22/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.9771 - loss: 0.0745 - val_accuracy: 0.9823 - val_loss: 0.0596
# Epoch 23/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.9820 - loss: 0.0543 - val_accuracy: 0.9727 - val_loss: 0.0827
# Epoch 24/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - accuracy: 0.9725 - loss: 0.0939 - val_accuracy: 0.9534 - val_loss: 0.1238
# Epoch 25/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.9672 - loss: 0.0684 - val_accuracy: 0.9469 - val_loss: 0.1448
# Epoch 26/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9729 - loss: 0.0929 - val_accuracy: 0.9759 - val_loss: 0.0676
# Epoch 27/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.9833 - loss: 0.0483 - val_accuracy: 0.9727 - val_loss: 0.0957
# Epoch 28/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 240ms/step - accuracy: 0.9280 - loss: 0.1754 - val_accuracy: 0.9695 - val_loss: 0.1000
# Epoch 29/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.8614 - loss: 0.4488 - val_accuracy: 0.9646 - val_loss: 0.1110
# Epoch 30/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - accuracy: 0.9781 - loss: 0.0838 - val_accuracy: 0.9807 - val_loss: 0.0640
# Epoch 31/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.9844 - loss: 0.0642 - val_accuracy: 0.9839 - val_loss: 0.0507
# Epoch 32/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - accuracy: 0.9755 - loss: 0.0921 - val_accuracy: 0.9887 - val_loss: 0.0316
# Epoch 33/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.9549 - loss: 0.1337 - val_accuracy: 0.9421 - val_loss: 0.1430
# Epoch 34/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - accuracy: 0.9223 - loss: 0.2511 - val_accuracy: 0.9904 - val_loss: 0.0361
# Epoch 35/35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - accuracy: 0.9859 - loss: 0.0527 - val_accuracy: 0.9678 - val_loss: 0.0977

# %% [markdown]
# Test the model

# %%
model.evaluate(test_ds)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9734 - loss: 0.1062
# [0.1650272160768509, 0.9548022747039795]

# %%
import numpy

plt.figure(figsize=(10,10))
for images, labels in test_ds.take(1):
  classifications = model(images)
  # print(classifications)

  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    index = numpy.argmax(classifications[i])
    plt.title("Pred: " + class_names[index] + " | Real: " + class_names[labels[i]])

# %% [markdown]
# Save the model

# %%
model.save('fruits.keras')
